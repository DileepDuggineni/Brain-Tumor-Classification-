# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

dataset_path = '/Users/siriduggineni/Downloads/archive (9)/'
train_path = os.path.join(dataset_path, 'training')
test_path = os.path.join(dataset_path, 'testing')

train_images = []
train_labels = []
for folder_name in os.listdir(train_path):
    folder_path = os.path.join(train_path, folder_name)
    for image_name in os.listdir(folder_path):
        image_path = os.path.join(folder_path, image_name)
        train_images.append(image_path)
        train_labels.append(folder_name)

test_images = []
test_labels = []
for folder_name in os.listdir(test_path):
    folder_path = os.path.join(test_path, folder_name)
    for image_name in os.listdir(folder_path):
        image_path = os.path.join(folder_path, image_name)
        test_images.append(image_path)
        test_labels.append(folder_name)


all_images = train_images + test_images
all_labels = train_labels + test_labels


combined_data = list(zip(all_images, all_labels))
np.random.shuffle(combined_data)
all_images, all_labels = zip(*combined_data)

train_images, val_test_images, train_labels, val_test_labels = train_test_split(all_images, all_labels, test_size=0.2, random_state=42)
val_images, test_images, val_labels, test_labels = train_test_split(val_test_images, val_test_labels, test_size=0.5, random_state=42)

# %%
import cv2
import matplotlib.pyplot as plt


def display_sample_images(image_paths, labels, num_samples=5):
    fig, axes = plt.subplots(1, num_samples, figsize=(15, 3))
    for i in range(num_samples):
        image = cv2.imread(image_paths[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        axes[i].imshow(image)
        axes[i].set_title(labels[i])
        axes[i].axis('off')
    plt.show()


print("Sample images from the training set:")
display_sample_images(train_images, train_labels)

print("Sample images from the validation set:")
display_sample_images(val_images, val_labels)

print("Sample images from the test set:")
display_sample_images(test_images, test_labels)
# Out:
# Sample images from the training set:
# Sample images from the validation set:
# Sample images from the test set:

# %%
import matplotlib.pyplot as plt

class_counts_train = {label: train_labels.count(label) for label in set(train_labels)}
class_counts_test = {label: test_labels.count(label) for label in set(test_labels)}

plt.figure(figsize=(12, 6))
plt.bar(class_counts_train.keys(), class_counts_train.values(), alpha=0.5, color='blue', label='Train')
plt.bar(class_counts_test.keys(), class_counts_test.values(), alpha=0.5, color='red', label='Test')
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.title('Class Distribution')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
from sklearn.model_selection import train_test_split

train_images, val_test_images, train_labels, val_test_labels = train_test_split(all_images, all_labels, test_size=0.2, random_state=42)
val_images, test_images, val_labels, test_labels = train_test_split(val_test_images, val_test_labels, test_size=0.5, random_state=42)

from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

label_encoder = LabelEncoder()
train_labels_encoded = label_encoder.fit_transform(train_labels)
val_labels_encoded = label_encoder.transform(val_labels)
test_labels_encoded = label_encoder.transform(test_labels)

y_train = to_categorical(train_labels_encoded)
y_val = to_categorical(val_labels_encoded)
y_test = to_categorical(test_labels_encoded)
img_width = 150
img_height = 150
def load_images(image_paths):
    images = []
    for image_path in image_paths:
        image = cv2.imread(image_path)
        image = cv2.resize(image, (img_width, img_height))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        images.append(image)
    return np.array(images)

train_images_array = load_images(train_images)
val_images_array = load_images(val_images)
test_images_array = load_images(test_images)

X_train = train_images_array / 255.0
X_val = val_images_array / 255.0
X_test = test_images_array / 255.0

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Resizing
from tensorflow.keras.models import Model
input_shape = (img_width, img_height, 3)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2

input_shape = (img_width, img_height, 3)

def vgg_16(input_shape, num_classes):
    model = Sequential()

    model.add(Conv2D(64, (3, 3), padding='same', input_shape=input_shape, kernel_initializer='he_normal', kernel_regularizer=l2(1e-4)))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal', kernel_regularizer=l2(1e-4)))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))

    model.add(Conv2D(128, (3, 3), padding='same', kernel_initializer='he_normal', kernel_regularizer=l2(1e-4)))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(Conv2D(128, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))

    model.add(Conv2D(256, (3, 3), padding='same', kernel_initializer='he_normal', kernel_regularizer=l2(1e-4)))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(Conv2D(256, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(Conv2D(256, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))

    model.add(Conv2D(512, (3, 3), padding='same', kernel_initializer='he_normal', kernel_regularizer=l2(1e-4)))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(Conv2D(512, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(Conv2D(512, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))

    model.add(Conv2D(512, (3, 3), padding='same', kernel_initializer='he_normal', kernel_regularizer=l2(1e-4)))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(Conv2D(512, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(Conv2D(512, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(tf.keras.layers.Activation('relu'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2)))

    model.add(Flatten())
    model.add(Dense(4096, activation='relu'))
    model.add(Dense(4096, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))

    return model

model= vgg_16(input_shape, 4)

model.compile(optimizer= 'adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 150, 150, 64)      1792
#
#  batch_normalization_1 (Bat  (None, 150, 150, 64)      256
#  chNormalization)
#
#  activation (Activation)     (None, 150, 150, 64)      0
#
#  conv2d_2 (Conv2D)           (None, 150, 150, 64)      36928
#
#  batch_normalization_2 (Bat  (None, 150, 150, 64)      256
#  chNormalization)
#
#  activation_1 (Activation)   (None, 150, 150, 64)      0
#
#  max_pooling2d (MaxPooling2  (None, 75, 75, 64)        0
#  D)
#
#  conv2d_3 (Conv2D)           (None, 75, 75, 128)       73856
#
#  batch_normalization_3 (Bat  (None, 75, 75, 128)       512
#  chNormalization)
#
#  activation_2 (Activation)   (None, 75, 75, 128)       0
#
#  conv2d_4 (Conv2D)           (None, 75, 75, 128)       147584
#
#  batch_normalization_4 (Bat  (None, 75, 75, 128)       512
#  chNormalization)
#
#  activation_3 (Activation)   (None, 75, 75, 128)       0
#
#  max_pooling2d_1 (MaxPoolin  (None, 37, 37, 128)       0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 256)       295168
#
#  batch_normalization_5 (Bat  (None, 37, 37, 256)       1024
#  chNormalization)
#
#  activation_4 (Activation)   (None, 37, 37, 256)       0
#
#  conv2d_6 (Conv2D)           (None, 37, 37, 256)       590080
#
#  batch_normalization_6 (Bat  (None, 37, 37, 256)       1024
#  chNormalization)
#
#  activation_5 (Activation)   (None, 37, 37, 256)       0
#
#  conv2d_7 (Conv2D)           (None, 37, 37, 256)       590080
#
#  batch_normalization_7 (Bat  (None, 37, 37, 256)       1024
#  chNormalization)
#
#  activation_6 (Activation)   (None, 37, 37, 256)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 18, 18, 256)       0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 18, 18, 512)       1180160
#
#  batch_normalization_8 (Bat  (None, 18, 18, 512)       2048
#  chNormalization)
#
#  activation_7 (Activation)   (None, 18, 18, 512)       0
#
#  conv2d_9 (Conv2D)           (None, 18, 18, 512)       2359808
#
#  batch_normalization_9 (Bat  (None, 18, 18, 512)       2048
#  chNormalization)
#
#  activation_8 (Activation)   (None, 18, 18, 512)       0
#
#  conv2d_10 (Conv2D)          (None, 18, 18, 512)       2359808
#
#  batch_normalization_10 (Ba  (None, 18, 18, 512)       2048
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 18, 18, 512)       0
#
#  max_pooling2d_3 (MaxPoolin  (None, 9, 9, 512)         0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 9, 9, 512)         2359808
#
#  batch_normalization_11 (Ba  (None, 9, 9, 512)         2048
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 9, 9, 512)         0
#
#  conv2d_12 (Conv2D)          (None, 9, 9, 512)         2359808
#
#  batch_normalization_12 (Ba  (None, 9, 9, 512)         2048
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 9, 9, 512)         0
#
#  conv2d_13 (Conv2D)          (None, 9, 9, 512)         2359808
#
#  batch_normalization_13 (Ba  (None, 9, 9, 512)         2048
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 9, 9, 512)         0
#
#  max_pooling2d_4 (MaxPoolin  (None, 4, 4, 512)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_2 (Dense)             (None, 4096)              33558528
#
#  dense_3 (Dense)             (None, 4096)              16781312
#
#  dense_4 (Dense)             (None, 4)                 16388
#
# =================================================================
# Total params: 65087812 (248.29 MB)
# Trainable params: 65079364 (248.26 MB)
# Non-trainable params: 8448 (33.00 KB)
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
batch_size = 64
checkpoint = ModelCheckpoint('DL_best_model_vgg.h5', monitor='val_accuracy', mode='max', save_best_only=True, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', restore_best_weights=True)
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=batch_size,
    validation_data=(X_val, y_val),
    callbacks=[checkpoint]
)

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/20
# 41/41 [==============================] - ETA: 0s - loss: 7.2078 - accuracy: 0.3209
# Epoch 1: val_accuracy improved from -inf to 0.18712, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 403s 10s/step - loss: 7.2078 - accuracy: 0.3209 - val_loss: 190.0249 - val_accuracy: 0.1871
# Epoch 2/20
# 41/41 [==============================] - ETA: 0s - loss: 1.5895 - accuracy: 0.4098
# Epoch 2: val_accuracy did not improve from 0.18712
# 41/41 [==============================] - 425s 10s/step - loss: 1.5895 - accuracy: 0.4098 - val_loss: 80.6863 - val_accuracy: 0.1779
# Epoch 3/20
# 41/41 [==============================] - ETA: 0s - loss: 1.4792 - accuracy: 0.4891
# Epoch 3: val_accuracy improved from 0.18712 to 0.28528, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 442s 11s/step - loss: 1.4792 - accuracy: 0.4891 - val_loss: 5.5610 - val_accuracy: 0.2853
# Epoch 4/20
# 41/41 [==============================] - ETA: 0s - loss: 1.4386 - accuracy: 0.4895
# Epoch 4: val_accuracy improved from 0.28528 to 0.32209, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 411s 10s/step - loss: 1.4386 - accuracy: 0.4895 - val_loss: 1.8100 - val_accuracy: 0.3221
# Epoch 5/20
# 41/41 [==============================] - ETA: 0s - loss: 1.4013 - accuracy: 0.4964
# Epoch 5: val_accuracy did not improve from 0.32209
# 41/41 [==============================] - 420s 10s/step - loss: 1.4013 - accuracy: 0.4964 - val_loss: 1.7711 - val_accuracy: 0.3190
# Epoch 6/20
# 41/41 [==============================] - ETA: 0s - loss: 1.3755 - accuracy: 0.5293
# Epoch 6: val_accuracy improved from 0.32209 to 0.33436, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 426s 10s/step - loss: 1.3755 - accuracy: 0.5293 - val_loss: 1.7659 - val_accuracy: 0.3344
# Epoch 7/20
# 41/41 [==============================] - ETA: 0s - loss: 1.2695 - accuracy: 0.5952
# Epoch 7: val_accuracy improved from 0.33436 to 0.36810, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 418s 10s/step - loss: 1.2695 - accuracy: 0.5952 - val_loss: 1.8238 - val_accuracy: 0.3681
# Epoch 8/20
# 41/41 [==============================] - ETA: 0s - loss: 1.1699 - accuracy: 0.6553
# Epoch 8: val_accuracy did not improve from 0.36810
# 41/41 [==============================] - 405s 10s/step - loss: 1.1699 - accuracy: 0.6553 - val_loss: 2.2545 - val_accuracy: 0.2730
# Epoch 9/20
# 41/41 [==============================] - ETA: 0s - loss: 1.1245 - accuracy: 0.6580
# Epoch 9: val_accuracy did not improve from 0.36810
# 41/41 [==============================] - 421s 10s/step - loss: 1.1245 - accuracy: 0.6580 - val_loss: 1.9766 - val_accuracy: 0.3497
# Epoch 10/20
# 41/41 [==============================] - ETA: 0s - loss: 1.0414 - accuracy: 0.6905
# Epoch 10: val_accuracy did not improve from 0.36810
# 41/41 [==============================] - 419s 10s/step - loss: 1.0414 - accuracy: 0.6905 - val_loss: 2.3561 - val_accuracy: 0.3282
# Epoch 11/20
# 41/41 [==============================] - ETA: 0s - loss: 0.9869 - accuracy: 0.7085
# Epoch 11: val_accuracy improved from 0.36810 to 0.40184, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 416s 10s/step - loss: 0.9869 - accuracy: 0.7085 - val_loss: 1.8655 - val_accuracy: 0.4018
# Epoch 12/20
# 41/41 [==============================] - ETA: 0s - loss: 0.9938 - accuracy: 0.7028
# Epoch 12: val_accuracy improved from 0.40184 to 0.46933, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 418s 10s/step - loss: 0.9938 - accuracy: 0.7028 - val_loss: 2.0284 - val_accuracy: 0.4693
# Epoch 13/20
# 41/41 [==============================] - ETA: 0s - loss: 0.9878 - accuracy: 0.7085
# Epoch 13: val_accuracy did not improve from 0.46933
# 41/41 [==============================] - 425s 10s/step - loss: 0.9878 - accuracy: 0.7085 - val_loss: 2.2961 - val_accuracy: 0.4693
# Epoch 14/20
# 41/41 [==============================] - ETA: 0s - loss: 0.8687 - accuracy: 0.7560
# Epoch 14: val_accuracy improved from 0.46933 to 0.60429, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 438s 11s/step - loss: 0.8687 - accuracy: 0.7560 - val_loss: 1.1701 - val_accuracy: 0.6043
# Epoch 15/20
# 41/41 [==============================] - ETA: 0s - loss: 0.8447 - accuracy: 0.7633
# Epoch 15: val_accuracy improved from 0.60429 to 0.61656, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 469s 11s/step - loss: 0.8447 - accuracy: 0.7633 - val_loss: 1.1921 - val_accuracy: 0.6166
# Epoch 16/20
# 41/41 [==============================] - ETA: 0s - loss: 0.8015 - accuracy: 0.7844
# Epoch 16: val_accuracy improved from 0.61656 to 0.75767, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 395s 10s/step - loss: 0.8015 - accuracy: 0.7844 - val_loss: 0.8324 - val_accuracy: 0.7577
# Epoch 17/20
# 41/41 [==============================] - ETA: 0s - loss: 0.8092 - accuracy: 0.7894
# Epoch 17: val_accuracy did not improve from 0.75767
# 41/41 [==============================] - 393s 10s/step - loss: 0.8092 - accuracy: 0.7894 - val_loss: 1.9836 - val_accuracy: 0.5613
# Epoch 18/20
# 41/41 [==============================] - ETA: 0s - loss: 0.7331 - accuracy: 0.8051
# Epoch 18: val_accuracy did not improve from 0.75767
# 41/41 [==============================] - 395s 10s/step - loss: 0.7331 - accuracy: 0.8051 - val_loss: 0.9716 - val_accuracy: 0.7117
# Epoch 19/20
# 41/41 [==============================] - ETA: 0s - loss: 0.7017 - accuracy: 0.8231
# Epoch 19: val_accuracy did not improve from 0.75767
# 41/41 [==============================] - 403s 10s/step - loss: 0.7017 - accuracy: 0.8231 - val_loss: 2.4412 - val_accuracy: 0.5890
# Epoch 20/20
# 41/41 [==============================] - ETA: 0s - loss: 0.7387 - accuracy: 0.8139
# Epoch 20: val_accuracy did not improve from 0.75767
# 41/41 [==============================] - 395s 10s/step - loss: 0.7387 - accuracy: 0.8139 - val_loss: 1.7897 - val_accuracy: 0.6043
# 11/11 [==============================] - 12s 1s/step - loss: 1.8648 - accuracy: 0.5872
# Test Accuracy: 0.5871559381484985

# %%
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=batch_size,
    validation_data=(X_val, y_val),
    callbacks=[checkpoint]
)

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/20
# 41/41 [==============================] - ETA: 0s - loss: 0.7286 - accuracy: 0.8139
# Epoch 1: val_accuracy did not improve from 0.75767
# 41/41 [==============================] - 400s 10s/step - loss: 0.7286 - accuracy: 0.8139 - val_loss: 2.5072 - val_accuracy: 0.4571
# Epoch 2/20
# 41/41 [==============================] - ETA: 0s - loss: 0.6643 - accuracy: 0.8441
# Epoch 2: val_accuracy did not improve from 0.75767
# 41/41 [==============================] - 397s 10s/step - loss: 0.6643 - accuracy: 0.8441 - val_loss: 1.9697 - val_accuracy: 0.5859
# Epoch 3/20
# 41/41 [==============================] - ETA: 0s - loss: 0.6323 - accuracy: 0.8499
# Epoch 3: val_accuracy improved from 0.75767 to 0.76994, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 398s 10s/step - loss: 0.6323 - accuracy: 0.8499 - val_loss: 0.8629 - val_accuracy: 0.7699
# Epoch 4/20
# 41/41 [==============================] - ETA: 0s - loss: 0.5580 - accuracy: 0.8797
# Epoch 4: val_accuracy improved from 0.76994 to 0.80982, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 411s 10s/step - loss: 0.5580 - accuracy: 0.8797 - val_loss: 0.7178 - val_accuracy: 0.8098
# Epoch 5/20
# 41/41 [==============================] - ETA: 0s - loss: 0.5297 - accuracy: 0.8882
# Epoch 5: val_accuracy did not improve from 0.80982
# 41/41 [==============================] - 404s 10s/step - loss: 0.5297 - accuracy: 0.8882 - val_loss: 1.4382 - val_accuracy: 0.5890
# Epoch 6/20
# 41/41 [==============================] - ETA: 0s - loss: 0.5876 - accuracy: 0.8598
# Epoch 6: val_accuracy did not improve from 0.80982
# 41/41 [==============================] - 407s 10s/step - loss: 0.5876 - accuracy: 0.8598 - val_loss: 0.9438 - val_accuracy: 0.7454
# Epoch 7/20
# 41/41 [==============================] - ETA: 0s - loss: 0.5057 - accuracy: 0.8951
# Epoch 7: val_accuracy did not improve from 0.80982
# 41/41 [==============================] - 431s 10s/step - loss: 0.5057 - accuracy: 0.8951 - val_loss: 0.8872 - val_accuracy: 0.7853
# Epoch 8/20
# 41/41 [==============================] - ETA: 0s - loss: 0.5397 - accuracy: 0.8840
# Epoch 8: val_accuracy did not improve from 0.80982
# 41/41 [==============================] - 437s 11s/step - loss: 0.5397 - accuracy: 0.8840 - val_loss: 2.0220 - val_accuracy: 0.6288
# Epoch 9/20
# 41/41 [==============================] - ETA: 0s - loss: 0.5155 - accuracy: 0.8916
# Epoch 9: val_accuracy did not improve from 0.80982
# 41/41 [==============================] - 413s 10s/step - loss: 0.5155 - accuracy: 0.8916 - val_loss: 0.8048 - val_accuracy: 0.7761
# Epoch 10/20
# 41/41 [==============================] - ETA: 0s - loss: 0.5205 - accuracy: 0.8859
# Epoch 10: val_accuracy improved from 0.80982 to 0.84663, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 408s 10s/step - loss: 0.5205 - accuracy: 0.8859 - val_loss: 0.6560 - val_accuracy: 0.8466
# Epoch 11/20
# 41/41 [==============================] - ETA: 0s - loss: 0.4703 - accuracy: 0.9077
# Epoch 11: val_accuracy did not improve from 0.84663
# 41/41 [==============================] - 406s 10s/step - loss: 0.4703 - accuracy: 0.9077 - val_loss: 0.8670 - val_accuracy: 0.8037
# Epoch 12/20
# 41/41 [==============================] - ETA: 0s - loss: 0.4456 - accuracy: 0.9111
# Epoch 12: val_accuracy did not improve from 0.84663
# 41/41 [==============================] - 426s 10s/step - loss: 0.4456 - accuracy: 0.9111 - val_loss: 2.0578 - val_accuracy: 0.6104
# Epoch 13/20
# 41/41 [==============================] - ETA: 0s - loss: 0.4132 - accuracy: 0.9268
# Epoch 13: val_accuracy did not improve from 0.84663
# 41/41 [==============================] - 750s 18s/step - loss: 0.4132 - accuracy: 0.9268 - val_loss: 0.6499 - val_accuracy: 0.8405
# Epoch 14/20
# 41/41 [==============================] - ETA: 0s - loss: 0.4104 - accuracy: 0.9184
# Epoch 14: val_accuracy did not improve from 0.84663
# 41/41 [==============================] - 415s 10s/step - loss: 0.4104 - accuracy: 0.9184 - val_loss: 0.9675 - val_accuracy: 0.7607
# Epoch 15/20
# 41/41 [==============================] - ETA: 0s - loss: 0.3787 - accuracy: 0.9353
# Epoch 15: val_accuracy improved from 0.84663 to 0.88037, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 411s 10s/step - loss: 0.3787 - accuracy: 0.9353 - val_loss: 0.5242 - val_accuracy: 0.8804
# Epoch 16/20
# 41/41 [==============================] - ETA: 0s - loss: 0.3657 - accuracy: 0.9360
# Epoch 16: val_accuracy did not improve from 0.88037
# 41/41 [==============================] - 408s 10s/step - loss: 0.3657 - accuracy: 0.9360 - val_loss: 1.1741 - val_accuracy: 0.7546
# Epoch 17/20
# 41/41 [==============================] - ETA: 0s - loss: 0.3493 - accuracy: 0.9422
# Epoch 17: val_accuracy did not improve from 0.88037
# 41/41 [==============================] - 405s 10s/step - loss: 0.3493 - accuracy: 0.9422 - val_loss: 0.5872 - val_accuracy: 0.8497
# Epoch 18/20
# 41/41 [==============================] - ETA: 0s - loss: 0.3429 - accuracy: 0.9410
# Epoch 18: val_accuracy did not improve from 0.88037
# 41/41 [==============================] - 403s 10s/step - loss: 0.3429 - accuracy: 0.9410 - val_loss: 2.3149 - val_accuracy: 0.6626
# Epoch 19/20
# 41/41 [==============================] - ETA: 0s - loss: 0.3007 - accuracy: 0.9560
# Epoch 19: val_accuracy did not improve from 0.88037
# 41/41 [==============================] - 404s 10s/step - loss: 0.3007 - accuracy: 0.9560 - val_loss: 1.1542 - val_accuracy: 0.7086
# Epoch 20/20
# 41/41 [==============================] - ETA: 0s - loss: 0.3327 - accuracy: 0.9399
# Epoch 20: val_accuracy did not improve from 0.88037
# 41/41 [==============================] - 406s 10s/step - loss: 0.3327 - accuracy: 0.9399 - val_loss: 0.8490 - val_accuracy: 0.7914
# 11/11 [==============================] - 12s 1s/step - loss: 0.9090 - accuracy: 0.7982
# Test Accuracy: 0.7981651425361633

# %%
from tensorflow.keras.models import load_model
model = load_model('DL_best_model_vgg.h5')

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# 11/11 [==============================] - 13s 1s/step - loss: 0.5022 - accuracy: 0.8838
# Test Accuracy: 0.8837920427322388

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import classification_report

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)

predicted_probabilities = model.predict(X_test)
predicted_classes = np.argmax(predicted_probabilities, axis=1)

predicted_labels = label_encoder.inverse_transform(predicted_classes)
true_labels = label_encoder.inverse_transform(np.argmax(y_test, axis=1))

report = classification_report(true_labels, predicted_labels)
print(report)
# Out:
# 11/11 [==============================] - 13s 1s/step - loss: 0.5022 - accuracy: 0.8838
# Test Loss: 0.5022455453872681
# Test Accuracy: 0.8837920427322388
# 11/11 [==============================] - 13s 1s/step
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.90      0.89      0.89       110
# meningioma_tumor       0.88      0.78      0.83        82
#         no_tumor       0.77      0.96      0.85        48
#  pituitary_tumor       0.95      0.93      0.94        87
#
#         accuracy                           0.88       327
#        macro avg       0.87      0.89      0.88       327
#     weighted avg       0.89      0.88      0.88       327

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle

n_classes = len(np.unique(true_labels))
binarized_true_labels = label_binarize(true_labels, classes=np.unique(true_labels))

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(binarized_true_labels[:, i], predicted_probabilities[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr["micro"], tpr["micro"], _ = roc_curve(binarized_true_labels.ravel(), predicted_probabilities.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

plt.figure()
lw = 2
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], lw=lw, label='ROC curve (area = %0.2f) for class %s' % (roc_auc[i], i))
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) curve')
plt.legend(loc="lower right")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
from tensorflow.keras.models import Model
import tensorflow as tf

sample_indices = np.random.choice(len(X_test), 5, replace=False)
sample_images = X_test[sample_indices]
sample_labels = true_labels[sample_indices]

sample_predicted_probabilities = model.predict(sample_images)
sample_predicted_labels = label_encoder.inverse_transform(np.argmax(sample_predicted_probabilities, axis=1))

plt.figure(figsize=(15, 10))
for i, (image, true_label, predicted_label) in enumerate(zip(sample_images, sample_labels, sample_predicted_labels)):
    plt.subplot(2, 5, i + 1)
    plt.imshow(image)
    plt.title(f"True: {true_label}\nPredicted: {predicted_label}")
    plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 261ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

predicted_probabilities = model.predict(X_test)
class_names = ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
predicted_labels = np.argmax(predicted_probabilities, axis=1)

true_labels = np.argmax(y_test, axis=1)

cm = confusion_matrix(true_labels, predicted_labels)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# 11/11 [==============================] - 13s 1s/step
