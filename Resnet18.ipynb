# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

dataset_path = '/Users/siriduggineni/Downloads/archive (9)/'
train_path = os.path.join(dataset_path, 'training')
test_path = os.path.join(dataset_path, 'testing')

train_images = []
train_labels = []
for folder_name in os.listdir(train_path):
    folder_path = os.path.join(train_path, folder_name)
    for image_name in os.listdir(folder_path):
        image_path = os.path.join(folder_path, image_name)
        train_images.append(image_path)
        train_labels.append(folder_name)

test_images = []
test_labels = []
for folder_name in os.listdir(test_path):
    folder_path = os.path.join(test_path, folder_name)
    for image_name in os.listdir(folder_path):
        image_path = os.path.join(folder_path, image_name)
        test_images.append(image_path)
        test_labels.append(folder_name)


all_images = train_images + test_images
all_labels = train_labels + test_labels


combined_data = list(zip(all_images, all_labels))
np.random.shuffle(combined_data)
all_images, all_labels = zip(*combined_data)

train_images, val_test_images, train_labels, val_test_labels = train_test_split(all_images, all_labels, test_size=0.2, random_state=42)
val_images, test_images, val_labels, test_labels = train_test_split(val_test_images, val_test_labels, test_size=0.5, random_state=42)

# %%
import cv2
import matplotlib.pyplot as plt


def display_sample_images(image_paths, labels, num_samples=5):
    fig, axes = plt.subplots(1, num_samples, figsize=(15, 3))
    for i in range(num_samples):
        image = cv2.imread(image_paths[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        axes[i].imshow(image)
        axes[i].set_title(labels[i])
        axes[i].axis('off')
    plt.show()


print("Sample images from the training set:")
display_sample_images(train_images, train_labels)

print("Sample images from the validation set:")
display_sample_images(val_images, val_labels)

print("Sample images from the test set:")
display_sample_images(test_images, test_labels)
# Out:
# Sample images from the training set:
# Sample images from the validation set:
# Sample images from the test set:

# %%
import matplotlib.pyplot as plt

class_counts_train = {label: train_labels.count(label) for label in set(train_labels)}
class_counts_test = {label: test_labels.count(label) for label in set(test_labels)}

plt.figure(figsize=(12, 6))
plt.bar(class_counts_train.keys(), class_counts_train.values(), alpha=0.5, color='blue', label='Train')
plt.bar(class_counts_test.keys(), class_counts_test.values(), alpha=0.5, color='red', label='Test')
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.title('Class Distribution')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
from sklearn.model_selection import train_test_split

train_images, val_test_images, train_labels, val_test_labels = train_test_split(all_images, all_labels, test_size=0.2, random_state=42)
val_images, test_images, val_labels, test_labels = train_test_split(val_test_images, val_test_labels, test_size=0.5, random_state=42)

from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

label_encoder = LabelEncoder()
train_labels_encoded = label_encoder.fit_transform(train_labels)
val_labels_encoded = label_encoder.transform(val_labels)
test_labels_encoded = label_encoder.transform(test_labels)

y_train = to_categorical(train_labels_encoded)
y_val = to_categorical(val_labels_encoded)
y_test = to_categorical(test_labels_encoded)
img_width = 150
img_height = 150
def load_images(image_paths):
    images = []
    for image_path in image_paths:
        image = cv2.imread(image_path)
        image = cv2.resize(image, (img_width, img_height))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        images.append(image)
    return np.array(images)

train_images_array = load_images(train_images)
val_images_array = load_images(val_images)
test_images_array = load_images(test_images)

X_train = train_images_array / 255.0
X_val = val_images_array / 255.0
X_test = test_images_array / 255.0

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Resizing
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
input_shape = (img_width, img_height, 3)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.regularizers import l2

input_shape = (img_width, img_height, 3)

from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, AveragePooling2D, Flatten, Dense
from keras.regularizers import l2

def BasicBlock(inputs, filters, stride=1):
    x = Conv2D(filters, kernel_size=3, strides=stride, padding='same', kernel_initializer='he_normal', kernel_regularizer=l2(1e-4))(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv2D(filters, kernel_size=3, strides=1, padding='same', kernel_initializer='he_normal', kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    
    shortcut = inputs
    if stride != 1 or inputs.shape[-1] != filters:
        shortcut = Conv2D(filters, kernel_size=1, strides=stride, padding='valid', kernel_initializer='he_normal', kernel_regularizer=l2(1e-4))(inputs)
        shortcut = BatchNormalization()(shortcut)
    
    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

def ResNet18(input_shape=(150, 150, 3), num_classes=4):
    inputs = Input(shape=input_shape)
    x = Conv2D(64, kernel_size=3, strides=1, padding='same', kernel_initializer='he_normal', kernel_regularizer=l2(1e-4))(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = BasicBlock(x, 64, stride=1)
    x = BasicBlock(x, 64, stride=1)
    
    x = BasicBlock(x, 128, stride=2)
    x = BasicBlock(x, 128, stride=1)
    
    x = BasicBlock(x, 256, stride=2)
    x = BasicBlock(x, 256, stride=1)
    
    x = BasicBlock(x, 512, stride=2)
    x = BasicBlock(x, 512, stride=1)
    
    x = AveragePooling2D(pool_size=(1, 1))(x)
    x = Flatten()(x)
    outputs = Dense(num_classes, activation='softmax', kernel_initializer='he_normal', kernel_regularizer=l2(1e-4))(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    return model

model = ResNet18(input_shape=input_shape, num_classes=4)

model.compile(optimizer= 'adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 150, 150, 64)         1792      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 150, 150, 64)         256       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 150, 150, 64)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 64)         36928     ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 150, 150, 64)         256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 150, 150, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 150, 150, 64)         36928     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 150, 150, 64)         256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 150, 150, 64)         0         ['batch_normalization_2[0][0]'
#                                                                     , 'activation[0][0]']
#
#  activation_2 (Activation)   (None, 150, 150, 64)         0         ['add[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 150, 150, 64)         36928     ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 150, 150, 64)         256       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 150, 150, 64)         0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 150, 150, 64)         36928     ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 150, 150, 64)         256       ['conv2d_4[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 150, 150, 64)         0         ['batch_normalization_4[0][0]'
#                                                                     , 'activation_2[0][0]']
#
#  activation_4 (Activation)   (None, 150, 150, 64)         0         ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 75, 75, 128)          73856     ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 75, 75, 128)          512       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 75, 75, 128)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 75, 75, 128)          147584    ['activation_5[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 75, 75, 128)          8320      ['activation_4[0][0]']
#
#  batch_normalization_6 (Bat  (None, 75, 75, 128)          512       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 75, 75, 128)          512       ['conv2d_7[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 75, 75, 128)          0         ['batch_normalization_6[0][0]'
#                                                                     , 'batch_normalization_7[0][0]
#                                                                     ']
#
#  activation_6 (Activation)   (None, 75, 75, 128)          0         ['add_2[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 75, 75, 128)          147584    ['activation_6[0][0]']
#
#  batch_normalization_8 (Bat  (None, 75, 75, 128)          512       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 75, 75, 128)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 75, 75, 128)          147584    ['activation_7[0][0]']
#
#  batch_normalization_9 (Bat  (None, 75, 75, 128)          512       ['conv2d_9[0][0]']
#  chNormalization)
#
#  add_3 (Add)                 (None, 75, 75, 128)          0         ['batch_normalization_9[0][0]'
#                                                                     , 'activation_6[0][0]']
#
#  activation_8 (Activation)   (None, 75, 75, 128)          0         ['add_3[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 38, 38, 256)          295168    ['activation_8[0][0]']
#
#  batch_normalization_10 (Ba  (None, 38, 38, 256)          1024      ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 38, 38, 256)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 38, 38, 256)          590080    ['activation_9[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 38, 38, 256)          33024     ['activation_8[0][0]']
#
#  batch_normalization_11 (Ba  (None, 38, 38, 256)          1024      ['conv2d_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_12 (Ba  (None, 38, 38, 256)          1024      ['conv2d_12[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 38, 38, 256)          0         ['batch_normalization_11[0][0]
#                                                                     ',
#                                                                      'batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_10 (Activation)  (None, 38, 38, 256)          0         ['add_4[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 38, 38, 256)          590080    ['activation_10[0][0]']
#
#  batch_normalization_13 (Ba  (None, 38, 38, 256)          1024      ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 38, 38, 256)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 38, 38, 256)          590080    ['activation_11[0][0]']
#
#  batch_normalization_14 (Ba  (None, 38, 38, 256)          1024      ['conv2d_14[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 38, 38, 256)          0         ['batch_normalization_14[0][0]
#                                                                     ',
#                                                                      'activation_10[0][0]']
#
#  activation_12 (Activation)  (None, 38, 38, 256)          0         ['add_5[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 19, 19, 512)          1180160   ['activation_12[0][0]']
#
#  batch_normalization_15 (Ba  (None, 19, 19, 512)          2048      ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 19, 19, 512)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 19, 19, 512)          2359808   ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 19, 19, 512)          131584    ['activation_12[0][0]']
#
#  batch_normalization_16 (Ba  (None, 19, 19, 512)          2048      ['conv2d_16[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 19, 19, 512)          2048      ['conv2d_17[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 19, 19, 512)          0         ['batch_normalization_16[0][0]
#                                                                     ',
#                                                                      'batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 19, 19, 512)          0         ['add_6[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 19, 19, 512)          2359808   ['activation_14[0][0]']
#
#  batch_normalization_18 (Ba  (None, 19, 19, 512)          2048      ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 19, 19, 512)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 19, 19, 512)          2359808   ['activation_15[0][0]']
#
#  batch_normalization_19 (Ba  (None, 19, 19, 512)          2048      ['conv2d_19[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 19, 19, 512)          0         ['batch_normalization_19[0][0]
#                                                                     ',
#                                                                      'activation_14[0][0]']
#
#  activation_16 (Activation)  (None, 19, 19, 512)          0         ['add_7[0][0]']
#
#  average_pooling2d (Average  (None, 19, 19, 512)          0         ['activation_16[0][0]']
#  Pooling2D)
#
#  flatten (Flatten)           (None, 184832)               0         ['average_pooling2d[0][0]']
#
#  dense (Dense)               (None, 4)                    739332    ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 11922564 (45.48 MB)
# Trainable params: 11912964 (45.44 MB)
# Non-trainable params: 9600 (37.50 KB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
batch_size = 64
checkpoint = ModelCheckpoint('DL_best_model_vgg.h5', monitor='val_accuracy', mode='max', save_best_only=True, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', restore_best_weights=True)
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=batch_size,
    validation_data=(X_val, y_val),
    callbacks=[checkpoint]
)

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/20
# 41/41 [==============================] - ETA: 0s - loss: 15.3234 - accuracy: 0.3508
# Epoch 1: val_accuracy improved from -inf to 0.31595, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 887s 22s/step - loss: 15.3234 - accuracy: 0.3508 - val_loss: 4744.8359 - val_accuracy: 0.3160
# Epoch 2/20
# /Applications/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 41/41 [==============================] - ETA: 0s - loss: 3.2424 - accuracy: 0.5584
# Epoch 2: val_accuracy did not improve from 0.31595
# 41/41 [==============================] - 854s 21s/step - loss: 3.2424 - accuracy: 0.5584 - val_loss: 299.9855 - val_accuracy: 0.2301
# Epoch 3/20
# 41/41 [==============================] - ETA: 0s - loss: 2.2294 - accuracy: 0.6787
# Epoch 3: val_accuracy did not improve from 0.31595
# 41/41 [==============================] - 871s 21s/step - loss: 2.2294 - accuracy: 0.6787 - val_loss: 39.2531 - val_accuracy: 0.1994
# Epoch 4/20
# 41/41 [==============================] - ETA: 0s - loss: 1.8859 - accuracy: 0.7675
# Epoch 4: val_accuracy did not improve from 0.31595
# 41/41 [==============================] - 860s 21s/step - loss: 1.8859 - accuracy: 0.7675 - val_loss: 32.3198 - val_accuracy: 0.1656
# Epoch 5/20
# 41/41 [==============================] - ETA: 0s - loss: 1.7322 - accuracy: 0.8250
# Epoch 5: val_accuracy improved from 0.31595 to 0.50920, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 871s 21s/step - loss: 1.7322 - accuracy: 0.8250 - val_loss: 2.2608 - val_accuracy: 0.5092
# Epoch 6/20
# 41/41 [==============================] - ETA: 0s - loss: 1.4341 - accuracy: 0.8782
# Epoch 6: val_accuracy did not improve from 0.50920
# 41/41 [==============================] - 884s 22s/step - loss: 1.4341 - accuracy: 0.8782 - val_loss: 2.7663 - val_accuracy: 0.3650
# Epoch 7/20
# 41/41 [==============================] - ETA: 0s - loss: 1.3461 - accuracy: 0.9020
# Epoch 7: val_accuracy did not improve from 0.50920
# 41/41 [==============================] - 842s 21s/step - loss: 1.3461 - accuracy: 0.9020 - val_loss: 2.5606 - val_accuracy: 0.3988
# Epoch 8/20
# 41/41 [==============================] - ETA: 0s - loss: 1.3158 - accuracy: 0.9242
# Epoch 8: val_accuracy improved from 0.50920 to 0.53988, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 907s 22s/step - loss: 1.3158 - accuracy: 0.9242 - val_loss: 2.5901 - val_accuracy: 0.5399
# Epoch 9/20
# 41/41 [==============================] - ETA: 0s - loss: 1.1611 - accuracy: 0.9460
# Epoch 9: val_accuracy improved from 0.53988 to 0.75460, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 878s 21s/step - loss: 1.1611 - accuracy: 0.9460 - val_loss: 1.6692 - val_accuracy: 0.7546
# Epoch 10/20
# 41/41 [==============================] - ETA: 0s - loss: 1.0803 - accuracy: 0.9697
# Epoch 10: val_accuracy improved from 0.75460 to 0.76994, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 937s 23s/step - loss: 1.0803 - accuracy: 0.9697 - val_loss: 1.6857 - val_accuracy: 0.7699
# Epoch 11/20
# 41/41 [==============================] - ETA: 0s - loss: 1.0123 - accuracy: 0.9797
# Epoch 11: val_accuracy improved from 0.76994 to 0.82209, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 952s 23s/step - loss: 1.0123 - accuracy: 0.9797 - val_loss: 1.5422 - val_accuracy: 0.8221
# Epoch 12/20
# 41/41 [==============================] - ETA: 0s - loss: 0.9881 - accuracy: 0.9786
# Epoch 12: val_accuracy improved from 0.82209 to 0.84049, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 2286s 57s/step - loss: 0.9881 - accuracy: 0.9786 - val_loss: 1.4127 - val_accuracy: 0.8405
# Epoch 13/20
# 41/41 [==============================] - ETA: 0s - loss: 1.0168 - accuracy: 0.9778
# Epoch 13: val_accuracy did not improve from 0.84049
# 41/41 [==============================] - 870s 21s/step - loss: 1.0168 - accuracy: 0.9778 - val_loss: 1.5841 - val_accuracy: 0.8160
# Epoch 14/20
# 41/41 [==============================] - ETA: 0s - loss: 0.9931 - accuracy: 0.9644
# Epoch 14: val_accuracy did not improve from 0.84049
# 41/41 [==============================] - 2952s 73s/step - loss: 0.9931 - accuracy: 0.9644 - val_loss: 1.5591 - val_accuracy: 0.7883
# Epoch 15/20
# 41/41 [==============================] - ETA: 0s - loss: 0.9338 - accuracy: 0.9824
# Epoch 15: val_accuracy improved from 0.84049 to 0.84663, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 1415s 35s/step - loss: 0.9338 - accuracy: 0.9824 - val_loss: 1.3854 - val_accuracy: 0.8466
# Epoch 16/20
# 41/41 [==============================] - ETA: 0s - loss: 0.8884 - accuracy: 0.9931
# Epoch 16: val_accuracy improved from 0.84663 to 0.88344, saving model to DL_best_model_vgg.h5
# 41/41 [==============================] - 1658s 40s/step - loss: 0.8884 - accuracy: 0.9931 - val_loss: 1.2961 - val_accuracy: 0.8834
# Epoch 17/20
# 41/41 [==============================] - ETA: 0s - loss: 0.8619 - accuracy: 0.9966
# Epoch 17: val_accuracy did not improve from 0.88344
# 41/41 [==============================] - 1393s 34s/step - loss: 0.8619 - accuracy: 0.9966 - val_loss: 1.2895 - val_accuracy: 0.8589
# Epoch 18/20
# 41/41 [==============================] - ETA: 0s - loss: 0.9045 - accuracy: 0.9912
# Epoch 18: val_accuracy did not improve from 0.88344
# 41/41 [==============================] - 1278s 31s/step - loss: 0.9045 - accuracy: 0.9912 - val_loss: 1.3568 - val_accuracy: 0.8558
# Epoch 19/20
# 41/41 [==============================] - ETA: 0s - loss: 0.8999 - accuracy: 0.9858
# Epoch 19: val_accuracy did not improve from 0.88344
# 41/41 [==============================] - 1181s 29s/step - loss: 0.8999 - accuracy: 0.9858 - val_loss: 1.4413 - val_accuracy: 0.8620
# Epoch 20/20
# 41/41 [==============================] - ETA: 0s - loss: 1.0014 - accuracy: 0.9636
# Epoch 20: val_accuracy did not improve from 0.88344
# 41/41 [==============================] - 967s 24s/step - loss: 1.0014 - accuracy: 0.9636 - val_loss: 2.7344 - val_accuracy: 0.8405
# 11/11 [==============================] - 28s 3s/step - loss: 3.9410 - accuracy: 0.8104
# Test Accuracy: 0.8103975653648376

# %%
checkpoint = ModelCheckpoint('DL_best_model_ResNet.h5', monitor='val_accuracy', mode='max', save_best_only=True, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', restore_best_weights=True)
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=batch_size,
    validation_data=(X_val, y_val),
    callbacks=[checkpoint]
)

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/20
# 41/41 [==============================] - ETA: 0s - loss: 0.8729 - accuracy: 0.9977
# Epoch 1: val_accuracy improved from -inf to 0.85276, saving model to DL_best_model_ResNet.h5
# 41/41 [==============================] - 832s 20s/step - loss: 0.8729 - accuracy: 0.9977 - val_loss: 1.3683 - val_accuracy: 0.8528
# Epoch 2/20
# /Applications/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 41/41 [==============================] - ETA: 0s - loss: 0.9972 - accuracy: 0.9843
# Epoch 2: val_accuracy improved from 0.85276 to 0.85890, saving model to DL_best_model_ResNet.h5
# 41/41 [==============================] - 811s 20s/step - loss: 0.9972 - accuracy: 0.9843 - val_loss: 1.2902 - val_accuracy: 0.8589
# Epoch 3/20
# 41/41 [==============================] - ETA: 0s - loss: 0.9075 - accuracy: 0.9854
# Epoch 3: val_accuracy did not improve from 0.85890
# 41/41 [==============================] - 852s 21s/step - loss: 0.9075 - accuracy: 0.9854 - val_loss: 1.4068 - val_accuracy: 0.8558
# Epoch 4/20
# 41/41 [==============================] - ETA: 0s - loss: 0.8751 - accuracy: 0.9828
# Epoch 4: val_accuracy did not improve from 0.85890
# 41/41 [==============================] - 830s 20s/step - loss: 0.8751 - accuracy: 0.9828 - val_loss: 1.4406 - val_accuracy: 0.8436
# Epoch 5/20
# 41/41 [==============================] - ETA: 0s - loss: 0.8397 - accuracy: 0.9851
# Epoch 5: val_accuracy did not improve from 0.85890
# 41/41 [==============================] - 823s 20s/step - loss: 0.8397 - accuracy: 0.9851 - val_loss: 2.5092 - val_accuracy: 0.8129
# Epoch 6/20
# 41/41 [==============================] - ETA: 0s - loss: 0.8682 - accuracy: 0.9874
# Epoch 6: val_accuracy did not improve from 0.85890
# 41/41 [==============================] - 767s 19s/step - loss: 0.8682 - accuracy: 0.9874 - val_loss: 1.7265 - val_accuracy: 0.8497
# Epoch 7/20
# 41/41 [==============================] - ETA: 0s - loss: 0.7937 - accuracy: 0.9931
# Epoch 7: val_accuracy improved from 0.85890 to 0.86503, saving model to DL_best_model_ResNet.h5
# 41/41 [==============================] - 765s 19s/step - loss: 0.7937 - accuracy: 0.9931 - val_loss: 1.3315 - val_accuracy: 0.8650
# Epoch 8/20
# 41/41 [==============================] - ETA: 0s - loss: 0.7912 - accuracy: 0.9912
# Epoch 8: val_accuracy did not improve from 0.86503
# 41/41 [==============================] - 763s 19s/step - loss: 0.7912 - accuracy: 0.9912 - val_loss: 1.4906 - val_accuracy: 0.8497
# Epoch 9/20
# 41/41 [==============================] - ETA: 0s - loss: 0.7594 - accuracy: 0.9943
# Epoch 9: val_accuracy improved from 0.86503 to 0.86810, saving model to DL_best_model_ResNet.h5
# 41/41 [==============================] - 764s 19s/step - loss: 0.7594 - accuracy: 0.9943 - val_loss: 1.2514 - val_accuracy: 0.8681
# Epoch 10/20
# 41/41 [==============================] - ETA: 0s - loss: 0.7618 - accuracy: 0.9935
# Epoch 10: val_accuracy did not improve from 0.86810
# 41/41 [==============================] - 765s 19s/step - loss: 0.7618 - accuracy: 0.9935 - val_loss: 1.4502 - val_accuracy: 0.8282
# Epoch 11/20
# 41/41 [==============================] - ETA: 0s - loss: 0.8132 - accuracy: 0.9805
# Epoch 11: val_accuracy did not improve from 0.86810
# 41/41 [==============================] - 756s 18s/step - loss: 0.8132 - accuracy: 0.9805 - val_loss: 1.7806 - val_accuracy: 0.8252
# Epoch 12/20
# 41/41 [==============================] - ETA: 0s - loss: 0.7174 - accuracy: 0.9958
# Epoch 12: val_accuracy did not improve from 0.86810
# 41/41 [==============================] - 850s 21s/step - loss: 0.7174 - accuracy: 0.9958 - val_loss: 1.4848 - val_accuracy: 0.8681
# Epoch 13/20
# 41/41 [==============================] - ETA: 0s - loss: 0.7139 - accuracy: 0.9958
# Epoch 13: val_accuracy did not improve from 0.86810
# 41/41 [==============================] - 832s 20s/step - loss: 0.7139 - accuracy: 0.9958 - val_loss: 1.4143 - val_accuracy: 0.8436
# Epoch 14/20
# 41/41 [==============================] - ETA: 0s - loss: 0.7232 - accuracy: 0.9870
# Epoch 14: val_accuracy did not improve from 0.86810
# 41/41 [==============================] - 1037s 25s/step - loss: 0.7232 - accuracy: 0.9870 - val_loss: 1.4697 - val_accuracy: 0.8620
# Epoch 15/20
# 41/41 [==============================] - ETA: 0s - loss: 0.8333 - accuracy: 0.9667
# Epoch 15: val_accuracy did not improve from 0.86810
# 41/41 [==============================] - 1505s 37s/step - loss: 0.8333 - accuracy: 0.9667 - val_loss: 1.7970 - val_accuracy: 0.8466
# Epoch 16/20
# 41/41 [==============================] - ETA: 0s - loss: 0.7625 - accuracy: 0.9824
# Epoch 16: val_accuracy did not improve from 0.86810
# 41/41 [==============================] - 815s 20s/step - loss: 0.7625 - accuracy: 0.9824 - val_loss: 7.8030 - val_accuracy: 0.4847
# Epoch 17/20
# 41/41 [==============================] - ETA: 0s - loss: 0.8779 - accuracy: 0.9755
# Epoch 17: val_accuracy did not improve from 0.86810
# 41/41 [==============================] - 776s 19s/step - loss: 0.8779 - accuracy: 0.9755 - val_loss: 2.9531 - val_accuracy: 0.6994
# Epoch 18/20
# 41/41 [==============================] - ETA: 0s - loss: 0.8016 - accuracy: 0.9701
# Epoch 18: val_accuracy did not improve from 0.86810
# 41/41 [==============================] - 772s 19s/step - loss: 0.8016 - accuracy: 0.9701 - val_loss: 1.7647 - val_accuracy: 0.8650
# Epoch 19/20
# 41/41 [==============================] - ETA: 0s - loss: 0.7209 - accuracy: 0.9820
# Epoch 19: val_accuracy did not improve from 0.86810
# 41/41 [==============================] - 765s 19s/step - loss: 0.7209 - accuracy: 0.9820 - val_loss: 1.5965 - val_accuracy: 0.8466
# Epoch 20/20
# 41/41 [==============================] - ETA: 0s - loss: 0.6530 - accuracy: 0.9923
# Epoch 20: val_accuracy did not improve from 0.86810
# 41/41 [==============================] - 770s 19s/step - loss: 0.6530 - accuracy: 0.9923 - val_loss: 1.4498 - val_accuracy: 0.8436
# 11/11 [==============================] - 23s 2s/step - loss: 1.7211 - accuracy: 0.8165
# Test Accuracy: 0.8165137767791748

# %%
from tensorflow.keras.models import load_model
model = load_model('DL_best_model_ResNet.h5')

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# 11/11 [==============================] - 23s 2s/step - loss: 1.3739 - accuracy: 0.8532
# Test Accuracy: 0.853210985660553

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import classification_report

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)

predicted_probabilities = model.predict(X_test)
predicted_classes = np.argmax(predicted_probabilities, axis=1)

predicted_labels = label_encoder.inverse_transform(predicted_classes)
true_labels = label_encoder.inverse_transform(np.argmax(y_test, axis=1))

report = classification_report(true_labels, predicted_labels)
print(report)
# Out:
# 11/11 [==============================] - 24s 2s/step - loss: 1.3739 - accuracy: 0.8532
# Test Loss: 1.3739405870437622
# Test Accuracy: 0.853210985660553
# 11/11 [==============================] - 24s 2s/step
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.86      0.80      0.83        99
# meningioma_tumor       0.82      0.74      0.78        96
#         no_tumor       0.78      0.95      0.86        42
#  pituitary_tumor       0.92      0.99      0.95        90
#
#         accuracy                           0.85       327
#        macro avg       0.84      0.87      0.85       327
#     weighted avg       0.85      0.85      0.85       327

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle

n_classes = len(np.unique(true_labels))
binarized_true_labels = label_binarize(true_labels, classes=np.unique(true_labels))

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(binarized_true_labels[:, i], predicted_probabilities[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr["micro"], tpr["micro"], _ = roc_curve(binarized_true_labels.ravel(), predicted_probabilities.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

plt.figure()
lw = 2
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], lw=lw, label='ROC curve (area = %0.2f) for class %s' % (roc_auc[i], i))
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) curve')
plt.legend(loc="lower right")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
from tensorflow.keras.models import Model
import tensorflow as tf

sample_indices = np.random.choice(len(X_test), 5, replace=False)
sample_images = X_test[sample_indices]
sample_labels = true_labels[sample_indices]

sample_predicted_probabilities = model.predict(sample_images)
sample_predicted_labels = label_encoder.inverse_transform(np.argmax(sample_predicted_probabilities, axis=1))

plt.figure(figsize=(15, 10))
for i, (image, true_label, predicted_label) in enumerate(zip(sample_images, sample_labels, sample_predicted_labels)):
    plt.subplot(2, 5, i + 1)
    plt.imshow(image)
    plt.title(f"True: {true_label}\nPredicted: {predicted_label}")
    plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 397ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

predicted_probabilities = model.predict(X_test)
class_names = ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
predicted_labels = np.argmax(predicted_probabilities, axis=1)

true_labels = np.argmax(y_test, axis=1)

cm = confusion_matrix(true_labels, predicted_labels)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# 11/11 [==============================] - 24s 2s/step
