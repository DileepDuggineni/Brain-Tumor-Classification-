# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

dataset_path = '/Users/siriduggineni/Downloads/archive (9)/'
train_path = os.path.join(dataset_path, 'training')
test_path = os.path.join(dataset_path, 'testing')

train_images = []
train_labels = []
for folder_name in os.listdir(train_path):
    folder_path = os.path.join(train_path, folder_name)
    for image_name in os.listdir(folder_path):
        image_path = os.path.join(folder_path, image_name)
        train_images.append(image_path)
        train_labels.append(folder_name)


test_images = []
test_labels = []
for folder_name in os.listdir(test_path):
    folder_path = os.path.join(test_path, folder_name)
    for image_name in os.listdir(folder_path):
        image_path = os.path.join(folder_path, image_name)
        test_images.append(image_path)
        test_labels.append(folder_name)


all_images = train_images + test_images
all_labels = train_labels + test_labels


combined_data = list(zip(all_images, all_labels))
np.random.shuffle(combined_data)
all_images, all_labels = zip(*combined_data)

train_images, val_test_images, train_labels, val_test_labels = train_test_split(all_images, all_labels, test_size=0.2, random_state=42)
val_images, test_images, val_labels, test_labels = train_test_split(val_test_images, val_test_labels, test_size=0.5, random_state=42)

# %%
import cv2
import matplotlib.pyplot as plt


def display_sample_images(image_paths, labels, num_samples=5):
    fig, axes = plt.subplots(1, num_samples, figsize=(15, 3))
    for i in range(num_samples):
        image = cv2.imread(image_paths[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        axes[i].imshow(image)
        axes[i].set_title(labels[i])
        axes[i].axis('off')
    plt.show()


print("Sample images from the training set:")
display_sample_images(train_images, train_labels)

print("Sample images from the validation set:")
display_sample_images(val_images, val_labels)

print("Sample images from the test set:")
display_sample_images(test_images, test_labels)
# Out:
# Sample images from the training set:
# Sample images from the validation set:
# Sample images from the test set:

# %%
import matplotlib.pyplot as plt


class_counts_train = {label: train_labels.count(label) for label in set(train_labels)}
class_counts_test = {label: test_labels.count(label) for label in set(test_labels)}

plt.figure(figsize=(12, 6))
plt.bar(class_counts_train.keys(), class_counts_train.values(), alpha=0.5, color='blue', label='Train')
plt.bar(class_counts_test.keys(), class_counts_test.values(), alpha=0.5, color='red', label='Test')
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.title('Class Distribution')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
from sklearn.model_selection import train_test_split

train_images, val_test_images, train_labels, val_test_labels = train_test_split(all_images, all_labels, test_size=0.2, random_state=42)
val_images, test_images, val_labels, test_labels = train_test_split(val_test_images, val_test_labels, test_size=0.5, random_state=42)

from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

label_encoder = LabelEncoder()
train_labels_encoded = label_encoder.fit_transform(train_labels)
val_labels_encoded = label_encoder.transform(val_labels)
test_labels_encoded = label_encoder.transform(test_labels)

y_train = to_categorical(train_labels_encoded)
y_val = to_categorical(val_labels_encoded)
y_test = to_categorical(test_labels_encoded)
img_width = 150
img_height = 150
def load_images(image_paths):
    images = []
    for image_path in image_paths:
        image = cv2.imread(image_path)
        image = cv2.resize(image, (img_width, img_height))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        images.append(image)
    return np.array(images)

train_images_array = load_images(train_images)
val_images_array = load_images(val_images)
test_images_array = load_images(test_images)

X_train = train_images_array / 255.0
X_val = val_images_array / 255.0
X_test = test_images_array / 255.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint

input_shape = (img_width, img_height, 3)

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=input_shape),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Dropout(0.1),
    Conv2D(64, (3,3), activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Dropout(0.1),
    Conv2D(128, (3,3), activation='relu'),
    Conv2D(128, (3,3), activation='relu'),
    Conv2D(128, (3,3), activation='relu'),
    Conv2D(256, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Dropout(0.3),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(512, activation='relu'),
    Dropout(0.1),
    Dense(4, activation='softmax')
])


model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 146, 146, 64)      18496
#
#  max_pooling2d (MaxPooling2  (None, 73, 73, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 73, 73, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 71, 71, 64)        36928
#
#  conv2d_3 (Conv2D)           (None, 69, 69, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 34, 34, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 34, 34, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 30, 30, 128)       147584
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 128)       147584
#
#  conv2d_7 (Conv2D)           (None, 26, 26, 256)       295168
#
#  max_pooling2d_2 (MaxPoolin  (None, 13, 13, 256)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 13, 13, 256)       0
#
#  flatten (Flatten)           (None, 43264)             0
#
#  dense (Dense)               (None, 512)               22151680
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 23173828 (88.40 MB)
# Trainable params: 23173828 (88.40 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint = ModelCheckpoint('DL_best_model_CNN.h5', monitor='val_accuracy', mode='max', save_best_only=True, verbose=1)
batch_size = 64
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=batch_size,
    validation_data=(X_val, y_val),
    callbacks=[checkpoint]
)

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/50
# 41/41 [==============================] - ETA: 0s - loss: 1.3590 - accuracy: 0.2999
# Epoch 1: val_accuracy improved from -inf to 0.29755, saving model to DL_best_model_CNN.h5
# 41/41 [==============================] - 98s 2s/step - loss: 1.3590 - accuracy: 0.2999 - val_loss: 1.3644 - val_accuracy: 0.2975
# Epoch 2/50
# /Applications/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 41/41 [==============================] - ETA: 0s - loss: 1.0878 - accuracy: 0.5450
# Epoch 2: val_accuracy improved from 0.29755 to 0.53374, saving model to DL_best_model_CNN.h5
# 41/41 [==============================] - 94s 2s/step - loss: 1.0878 - accuracy: 0.5450 - val_loss: 1.0223 - val_accuracy: 0.5337
# Epoch 3/50
# 41/41 [==============================] - ETA: 0s - loss: 0.8487 - accuracy: 0.6381
# Epoch 3: val_accuracy improved from 0.53374 to 0.64417, saving model to DL_best_model_CNN.h5
# 41/41 [==============================] - 90s 2s/step - loss: 0.8487 - accuracy: 0.6381 - val_loss: 0.8545 - val_accuracy: 0.6442
# Epoch 4/50
# 41/41 [==============================] - ETA: 0s - loss: 0.7194 - accuracy: 0.6890
# Epoch 4: val_accuracy improved from 0.64417 to 0.67485, saving model to DL_best_model_CNN.h5
# 41/41 [==============================] - 89s 2s/step - loss: 0.7194 - accuracy: 0.6890 - val_loss: 0.7381 - val_accuracy: 0.6748
# Epoch 5/50
# 41/41 [==============================] - ETA: 0s - loss: 0.6377 - accuracy: 0.7438
# Epoch 5: val_accuracy improved from 0.67485 to 0.74540, saving model to DL_best_model_CNN.h5
# 41/41 [==============================] - 88s 2s/step - loss: 0.6377 - accuracy: 0.7438 - val_loss: 0.6765 - val_accuracy: 0.7454
# Epoch 6/50
# 41/41 [==============================] - ETA: 0s - loss: 0.5065 - accuracy: 0.7985
# Epoch 6: val_accuracy improved from 0.74540 to 0.80368, saving model to DL_best_model_CNN.h5
# 41/41 [==============================] - 94s 2s/step - loss: 0.5065 - accuracy: 0.7985 - val_loss: 0.5310 - val_accuracy: 0.8037
# Epoch 7/50
# 41/41 [==============================] - ETA: 0s - loss: 0.3903 - accuracy: 0.8476
# Epoch 7: val_accuracy improved from 0.80368 to 0.84663, saving model to DL_best_model_CNN.h5
# 41/41 [==============================] - 97s 2s/step - loss: 0.3903 - accuracy: 0.8476 - val_loss: 0.4853 - val_accuracy: 0.8466
# Epoch 8/50
# 41/41 [==============================] - ETA: 0s - loss: 0.2964 - accuracy: 0.8843
# Epoch 8: val_accuracy did not improve from 0.84663
# 41/41 [==============================] - 93s 2s/step - loss: 0.2964 - accuracy: 0.8843 - val_loss: 0.4734 - val_accuracy: 0.8313
# Epoch 9/50
# 41/41 [==============================] - ETA: 0s - loss: 0.2308 - accuracy: 0.9085
# Epoch 9: val_accuracy did not improve from 0.84663
# 41/41 [==============================] - 91s 2s/step - loss: 0.2308 - accuracy: 0.9085 - val_loss: 0.4925 - val_accuracy: 0.8466
# Epoch 10/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1578 - accuracy: 0.9452
# Epoch 10: val_accuracy improved from 0.84663 to 0.84969, saving model to DL_best_model_CNN.h5
# 41/41 [==============================] - 92s 2s/step - loss: 0.1578 - accuracy: 0.9452 - val_loss: 0.4189 - val_accuracy: 0.8497
# Epoch 11/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9567
# Epoch 11: val_accuracy improved from 0.84969 to 0.88344, saving model to DL_best_model_CNN.h5
# 41/41 [==============================] - 92s 2s/step - loss: 0.1320 - accuracy: 0.9567 - val_loss: 0.3689 - val_accuracy: 0.8834
# Epoch 12/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1034 - accuracy: 0.9640
# Epoch 12: val_accuracy did not improve from 0.88344
# 41/41 [==============================] - 89s 2s/step - loss: 0.1034 - accuracy: 0.9640 - val_loss: 0.4900 - val_accuracy: 0.8773
# Epoch 13/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1596 - accuracy: 0.9475
# Epoch 13: val_accuracy did not improve from 0.88344
# 41/41 [==============================] - 91s 2s/step - loss: 0.1596 - accuracy: 0.9475 - val_loss: 0.4465 - val_accuracy: 0.8528
# Epoch 14/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0664 - accuracy: 0.9759
# Epoch 14: val_accuracy did not improve from 0.88344
# 41/41 [==============================] - 92s 2s/step - loss: 0.0664 - accuracy: 0.9759 - val_loss: 0.5163 - val_accuracy: 0.8681
# Epoch 15/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0638 - accuracy: 0.9766
# Epoch 15: val_accuracy did not improve from 0.88344
# 41/41 [==============================] - 91s 2s/step - loss: 0.0638 - accuracy: 0.9766 - val_loss: 0.5068 - val_accuracy: 0.8681
# Epoch 16/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9900
# Epoch 16: val_accuracy improved from 0.88344 to 0.89264, saving model to DL_best_model_CNN.h5
# 41/41 [==============================] - 94s 2s/step - loss: 0.0397 - accuracy: 0.9900 - val_loss: 0.5015 - val_accuracy: 0.8926
# Epoch 17/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9847
# Epoch 17: val_accuracy did not improve from 0.89264
# 41/41 [==============================] - 93s 2s/step - loss: 0.0436 - accuracy: 0.9847 - val_loss: 0.4892 - val_accuracy: 0.8865
# Epoch 18/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0420 - accuracy: 0.9866
# Epoch 18: val_accuracy did not improve from 0.89264
# 41/41 [==============================] - 92s 2s/step - loss: 0.0420 - accuracy: 0.9866 - val_loss: 0.5741 - val_accuracy: 0.8865
# Epoch 19/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9881
# Epoch 19: val_accuracy did not improve from 0.89264
# 41/41 [==============================] - 90s 2s/step - loss: 0.0442 - accuracy: 0.9881 - val_loss: 0.4360 - val_accuracy: 0.8926
# Epoch 20/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0219 - accuracy: 0.9935
# Epoch 20: val_accuracy improved from 0.89264 to 0.89877, saving model to DL_best_model_CNN.h5
# 41/41 [==============================] - 131s 3s/step - loss: 0.0219 - accuracy: 0.9935 - val_loss: 0.4425 - val_accuracy: 0.8988
# Epoch 21/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 0.9927
# Epoch 21: val_accuracy did not improve from 0.89877
# 41/41 [==============================] - 125s 3s/step - loss: 0.0224 - accuracy: 0.9927 - val_loss: 0.4738 - val_accuracy: 0.8957
# Epoch 22/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9943
# Epoch 22: val_accuracy improved from 0.89877 to 0.90491, saving model to DL_best_model_CNN.h5
# 41/41 [==============================] - 92s 2s/step - loss: 0.0185 - accuracy: 0.9943 - val_loss: 0.4456 - val_accuracy: 0.9049
# Epoch 23/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9858
# Epoch 23: val_accuracy did not improve from 0.90491
# 41/41 [==============================] - 108s 3s/step - loss: 0.0387 - accuracy: 0.9858 - val_loss: 0.5206 - val_accuracy: 0.8957
# Epoch 24/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.9893
# Epoch 24: val_accuracy did not improve from 0.90491
# 41/41 [==============================] - 176s 4s/step - loss: 0.0329 - accuracy: 0.9893 - val_loss: 0.5727 - val_accuracy: 0.9018
# Epoch 25/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0383 - accuracy: 0.9908
# Epoch 25: val_accuracy did not improve from 0.90491
# 41/41 [==============================] - 179s 4s/step - loss: 0.0383 - accuracy: 0.9908 - val_loss: 0.4805 - val_accuracy: 0.8681
# Epoch 26/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0317 - accuracy: 0.9908
# Epoch 26: val_accuracy improved from 0.90491 to 0.90798, saving model to DL_best_model_CNN.h5
# 41/41 [==============================] - 177s 4s/step - loss: 0.0317 - accuracy: 0.9908 - val_loss: 0.4248 - val_accuracy: 0.9080
# Epoch 27/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9920
# Epoch 27: val_accuracy did not improve from 0.90798
# 41/41 [==============================] - 175s 4s/step - loss: 0.0241 - accuracy: 0.9920 - val_loss: 0.5018 - val_accuracy: 0.9018
# Epoch 28/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9916
# Epoch 28: val_accuracy did not improve from 0.90798
# 41/41 [==============================] - 179s 4s/step - loss: 0.0305 - accuracy: 0.9916 - val_loss: 0.4908 - val_accuracy: 0.8804
# Epoch 29/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 0.9966
# Epoch 29: val_accuracy did not improve from 0.90798
# 41/41 [==============================] - 182s 4s/step - loss: 0.0144 - accuracy: 0.9966 - val_loss: 0.4465 - val_accuracy: 0.9018
# Epoch 30/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9946
# Epoch 30: val_accuracy did not improve from 0.90798
# 41/41 [==============================] - 177s 4s/step - loss: 0.0160 - accuracy: 0.9946 - val_loss: 0.5133 - val_accuracy: 0.8865
# Epoch 31/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9977
# Epoch 31: val_accuracy did not improve from 0.90798
# 41/41 [==============================] - 176s 4s/step - loss: 0.0097 - accuracy: 0.9977 - val_loss: 0.5511 - val_accuracy: 0.8834
# Epoch 32/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9973
# Epoch 32: val_accuracy did not improve from 0.90798
# 41/41 [==============================] - 178s 4s/step - loss: 0.0062 - accuracy: 0.9973 - val_loss: 0.5392 - val_accuracy: 0.9049
# Epoch 33/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9977
# Epoch 33: val_accuracy did not improve from 0.90798
# 41/41 [==============================] - 177s 4s/step - loss: 0.0068 - accuracy: 0.9977 - val_loss: 0.7193 - val_accuracy: 0.8988
# Epoch 34/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9958
# Epoch 34: val_accuracy did not improve from 0.90798
# 41/41 [==============================] - 182s 4s/step - loss: 0.0077 - accuracy: 0.9958 - val_loss: 0.6647 - val_accuracy: 0.9080
# Epoch 35/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9954
# Epoch 35: val_accuracy did not improve from 0.90798
# 41/41 [==============================] - 180s 4s/step - loss: 0.0124 - accuracy: 0.9954 - val_loss: 0.6054 - val_accuracy: 0.9018
# Epoch 36/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9908
# Epoch 36: val_accuracy did not improve from 0.90798
# 41/41 [==============================] - 178s 4s/step - loss: 0.0309 - accuracy: 0.9908 - val_loss: 0.4254 - val_accuracy: 0.9018
# Epoch 37/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9939
# Epoch 37: val_accuracy improved from 0.90798 to 0.91718, saving model to DL_best_model_CNN.h5
# 41/41 [==============================] - 175s 4s/step - loss: 0.0189 - accuracy: 0.9939 - val_loss: 0.4415 - val_accuracy: 0.9172
# Epoch 38/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0752 - accuracy: 0.9805
# Epoch 38: val_accuracy did not improve from 0.91718
# 41/41 [==============================] - 177s 4s/step - loss: 0.0752 - accuracy: 0.9805 - val_loss: 0.6577 - val_accuracy: 0.8834
# Epoch 39/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0724 - accuracy: 0.9763
# Epoch 39: val_accuracy did not improve from 0.91718
# 41/41 [==============================] - 178s 4s/step - loss: 0.0724 - accuracy: 0.9763 - val_loss: 0.5110 - val_accuracy: 0.8957
# Epoch 40/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9916
# Epoch 40: val_accuracy did not improve from 0.91718
# 41/41 [==============================] - 177s 4s/step - loss: 0.0284 - accuracy: 0.9916 - val_loss: 0.5406 - val_accuracy: 0.8957
# Epoch 41/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9923
# Epoch 41: val_accuracy did not improve from 0.91718
# 41/41 [==============================] - 174s 4s/step - loss: 0.0233 - accuracy: 0.9923 - val_loss: 0.6505 - val_accuracy: 0.9049
# Epoch 42/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9969
# Epoch 42: val_accuracy did not improve from 0.91718
# 41/41 [==============================] - 175s 4s/step - loss: 0.0087 - accuracy: 0.9969 - val_loss: 0.6124 - val_accuracy: 0.9141
# Epoch 43/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9950
# Epoch 43: val_accuracy did not improve from 0.91718
# 41/41 [==============================] - 177s 4s/step - loss: 0.0208 - accuracy: 0.9950 - val_loss: 0.6834 - val_accuracy: 0.8865
# Epoch 44/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9881
# Epoch 44: val_accuracy did not improve from 0.91718
# 41/41 [==============================] - 177s 4s/step - loss: 0.0319 - accuracy: 0.9881 - val_loss: 0.6580 - val_accuracy: 0.9110
# Epoch 45/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.9950
# Epoch 45: val_accuracy did not improve from 0.91718
# 41/41 [==============================] - 173s 4s/step - loss: 0.0214 - accuracy: 0.9950 - val_loss: 0.5754 - val_accuracy: 0.9141
# Epoch 46/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9989
# Epoch 46: val_accuracy did not improve from 0.91718
# 41/41 [==============================] - 170s 4s/step - loss: 0.0052 - accuracy: 0.9989 - val_loss: 0.6701 - val_accuracy: 0.9110
# Epoch 47/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9989
# Epoch 47: val_accuracy did not improve from 0.91718
# 41/41 [==============================] - 172s 4s/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.6684 - val_accuracy: 0.9172
# Epoch 48/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9992
# Epoch 48: val_accuracy improved from 0.91718 to 0.92025, saving model to DL_best_model_CNN.h5
# 41/41 [==============================] - 173s 4s/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.7220 - val_accuracy: 0.9202
# Epoch 49/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9985
# Epoch 49: val_accuracy did not improve from 0.92025
# 41/41 [==============================] - 174s 4s/step - loss: 0.0035 - accuracy: 0.9985 - val_loss: 0.7609 - val_accuracy: 0.9110
# Epoch 50/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9966
# Epoch 50: val_accuracy did not improve from 0.92025
# 41/41 [==============================] - 174s 4s/step - loss: 0.0109 - accuracy: 0.9966 - val_loss: 0.7808 - val_accuracy: 0.8926
# 11/11 [==============================] - 5s 428ms/step - loss: 0.5786 - accuracy: 0.9297
# Test Accuracy: 0.9296635985374451

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.models import load_model
model = load_model('DL_best_model_CNN.h5')

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# 11/11 [==============================] - 5s 454ms/step - loss: 0.6535 - accuracy: 0.9450
# Test Accuracy: 0.9449541568756104

# %%
from sklearn.metrics import classification_report
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)

predicted_probabilities = model.predict(X_test)
predicted_classes = np.argmax(predicted_probabilities, axis=1)

predicted_labels = label_encoder.inverse_transform(predicted_classes)
true_labels = label_encoder.inverse_transform(np.argmax(y_test, axis=1))

report = classification_report(true_labels, predicted_labels)
print(report)
# Out:
# 11/11 [==============================] - 3s 248ms/step - loss: 0.6535 - accuracy: 0.9450
# Test Loss: 0.6534695625305176
# Test Accuracy: 0.9449541568756104
# 11/11 [==============================] - 3s 244ms/step
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.97      0.87      0.92        95
# meningioma_tumor       0.91      0.95      0.93        88
#         no_tumor       0.92      0.94      0.93        35
#  pituitary_tumor       0.96      1.00      0.98       109
#
#         accuracy                           0.94       327
#        macro avg       0.94      0.94      0.94       327
#     weighted avg       0.95      0.94      0.94       327

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle

n_classes = len(np.unique(true_labels))
binarized_true_labels = label_binarize(true_labels, classes=np.unique(true_labels))

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(binarized_true_labels[:, i], predicted_probabilities[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr["micro"], tpr["micro"], _ = roc_curve(binarized_true_labels.ravel(), predicted_probabilities.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

plt.figure()
lw = 2
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], lw=lw, label='ROC curve (area = %0.2f) for class %s' % (roc_auc[i], i))
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) curve')
plt.legend(loc="lower right")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
from tensorflow.keras.models import Model
import tensorflow as tf

sample_indices = np.random.choice(len(y_test), 5, replace=False)
sample_images = X_test[sample_indices]
sample_labels = true_labels[sample_indices]

sample_predicted_probabilities = model.predict(sample_images)
sample_predicted_labels = label_encoder.inverse_transform(np.argmax(sample_predicted_probabilities, axis=1))

plt.figure(figsize=(15, 10))
for i, (image, true_label, predicted_label) in enumerate(zip(sample_images, sample_labels, sample_predicted_labels)):
    plt.subplot(2, 5, i + 1)
    plt.imshow(image)
    plt.title(f"True: {true_label}\nPredicted: {predicted_label}")
    plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 64ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

predicted_probabilities = model.predict(X_test)
class_names = ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
predicted_labels = np.argmax(predicted_probabilities, axis=1)

true_labels = np.argmax(y_test, axis=1)

cm = confusion_matrix(true_labels, predicted_labels)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# 11/11 [==============================] - 3s 234ms/step
